# %% [markdown]
# $2a + 3b = 8$<br>
# $10a + 1b = 13$
#
# Solve with 2 Method:
#
# 1. Substitional Equation
#
#     (1)... $2a + 3b = 8$ <br>
#     (2)... $10a + 1b = 13$
#
#     (1) * 5 = (3) <br>
#     (3) - (2) : </br>
#
#     $b = \frac{27}{14}$
#
#     Substitute $b$ into (1) and Solve $a$:
#
#     $a = \frac{31}{28}$
#
#
#
# 2. Matrices
#
# $\begin{pmatrix}
# 2 & 3 \\
# 10 & 1
# \end{pmatrix}
# \begin{bmatrix}
# a \\
# b
# \end{bmatrix}$ = $\begin{bmatrix} 8 \\ 3 \end{bmatrix}$

# %% [markdown]
# ### Vector
#
# * Magnitude
# * Direction
#
# $\overrightarrow{v} = (x,y) = \begin{bmatrix} x \\ y \end{bmatrix} $
#
# $\mathbb{R^N} , \text{Real Coordinate Space}$
